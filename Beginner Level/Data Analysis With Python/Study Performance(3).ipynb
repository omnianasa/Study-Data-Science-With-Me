# %% [markdown]
# # Study Performance Dataset IEEE Task
# using dataset from Kaggle, I will explain pandas library and its usage with datasets and data analysis
# The link of the data on kaggle:
# https://www.kaggle.com/datasets/bhavikjikadara/student-study-performance
#
# About the data:
# This project understands how the student's performance (test scores) is affected by other variables such as Gender, Ethnicity, Parental level of education, Lunch and Test preparation course.
#
# This data set consists of the marks secured by the students in various subjects.
#
#  1/ gender : sex of students -> (Male/female)
#
#  2/ race/ethnicity : ethnicity of students -> (Group A, B,C, D,E)
#
#  3/ parental level of education : parents' final education ->(bachelor's degree,some college,master's degree,associate's degree,- high school)
#
#  4/ lunch : having lunch before test (standard or free/reduced)
#
#  5/ test preparation course : complete or not complete before test
#
#  6/ math score
#
#  7/ reading score
#
#  8/ writing score

# %% [markdown]
# ![dataset-cover.png](attachment:dataset-cover.png)

# %%
# import main libraies needed
import pandas as pd
import numpy as np

# %%
# reading the data from a csv file
data = pd.read_csv('study_performance.csv' )

# %%
data
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %% [markdown]
# # About Data

# %%
# get the shape of data (matrix rows and columns numbers)
data.shape
# Out:
# (1000, 8)

# %%
# get the main info of the data in cluding column names, data types and non null values
data.info()
# from the output we got that there is not null values and data types include: (object and integers)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# get the main statistics from the data
data.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
# get the first 5 rows
data.head(5)
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# get the last 3 rows
data.tail(3)
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %% [markdown]
# # Slicing & Access rows and columns

# %% [markdown]
# ### columns

# %%
# accessing a specifiec column in the dataset
data['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
# accessing two or more columns in the dataset
data[['gender' , 'lunch']]
# Out:
#      gender         lunch
# 0    female      standard
# 1    female      standard
# 2    female      standard
# 3      male  free/reduced
# 4      male      standard
# ..      ...           ...
# 995  female      standard
# 996    male  free/reduced
# 997  female  free/reduced
# 998  female      standard
# 999  female  free/reduced
#
# [1000 rows x 2 columns]

# %%
# getting the columns names of the dataset
data.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %%
# compare unique values count of the column
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# ### Rows

# %%
# get a specifiec one row using iloc function
data.iloc[0]
# Out:
# gender                                    female
# race_ethnicity                           group B
# parental_level_of_education    bachelor's degree
# lunch                                   standard
# test_preparation_course                     none
# math_score                                    72
# reading_score                                 72
# writing_score                                 74
# Name: 0, dtype: object

# %%
# get a specifiec two or more rows using iloc function
data.iloc[[0, 10, 100]]
# Out:
#      gender race_ethnicity parental_level_of_education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 10     male        group C          associate's degree  standard
# 100    male        group B                some college  standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 0                      none          72             72             74
# 10                     none          58             54             52
# 100                    none          79             67             67

# %%
# slicing with loc function with a one or more column name
data.loc[0:5, ['gender', 'math_score']]
# Out:
#    gender  math_score
# 0  female          72
# 1  female          69
# 2  female          90
# 3    male          47
# 4    male          76
# 5  female          71

# %% [markdown]
# ### index

# %%
# define the index col in df definition above using index_col = "col_name"
data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# iloc search by index but loc search by value in index col
data.loc[900]
# Out:
# gender                                    male
# race_ethnicity                         group D
# parental_level_of_education    master's degree
# lunch                                 standard
# test_preparation_course                   none
# math_score                                  85
# reading_score                               84
# writing_score                               89
# Name: 900, dtype: object

# %%
# sort index col of the data
data.sort_index(inplace = True)

# %% [markdown]
# # Filtering the data

# %%
# get the values of math score column over than 95 and assign it in variable filt
filt = (data["math_score"] >= 95)
# Access the data with that filter method 
data[filt]
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 34     male        group E                some college      standard
# 104    male        group C                some college      standard
# 114  female        group E           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 263  female        group E                 high school      standard
# 286    male        group E          associate's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 503  female        group E          associate's degree      standard
# 539    male        group A          associate's degree      standard
# ...

# %%
# the same above can be determined in one line 
data[data["math_score"] >= 95]
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 34     male        group E                some college      standard
# 104    male        group C                some college      standard
# 114  female        group E           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 263  female        group E                 high school      standard
# 286    male        group E          associate's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 503  female        group E          associate's degree      standard
# 539    male        group A          associate's degree      standard
# ...

# %%
# filter by two or more conditions using and , or and not operators and locate them with a specifiec col.
filt = (data["gender"] == "male") & (data["math_score"] > 50)
data.loc[filt , "lunch"]
# Out:
# 4          standard
# 8      free/reduced
# 10         standard
# 13         standard
# 16         standard
#            ...
# 985        standard
# 987        standard
# 990    free/reduced
# 994        standard
# 996    free/reduced
# Name: lunch, Length: 429, dtype: object

# %%
# filter by a givin list 
reading_score = list(i for i in range (90 , 101))
filt2 = data['parental_level_of_education'].isin(reading_score)
data.loc[filt , "parental_level_of_education"]
# Out:
# 4            some college
# 8             high school
# 10     associate's degree
# 13           some college
# 16            high school
#               ...
# 985           high school
# 987      some high school
# 990           high school
# 994           high school
# 996           high school
# Name: parental_level_of_education, Length: 429, dtype: object

# %%
#filter by a string
filt = data['lunch'].str.contains("free")
data[filt]
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %% [markdown]
# # Updating Data

# %%
data.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %%
# get all column names in upper case 
data.columns = [x.upper() for x in  data.columns]

# replace every _ in string with space
data.columns = data.columns.str.replace("_" , " ")
data
# Out:
#      GENDER RACE ETHNICITY PARENTAL LEVEL OF EDUCATION         LUNCH  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     TEST PREPARATION COURSE  MATH SCORE  READING SCORE  WRITING SCORE
# ...

# %%
# rename column name
data.rename(columns = {"RACE ETHNICITY" : "RACE"} , inplace = True)

# %%
# updating the entire info of a row
data.loc[2, "GENDER"] = "male"

# %%
# lower or upper a column 
data["RACE"] = data["RACE"].str.lower()

# %%
data.head(3)
# Out:
#    GENDER     RACE PARENTAL LEVEL OF EDUCATION     LUNCH  \
# 0  female  group b           bachelor's degree  standard
# 1  female  group c                some college  standard
# 2    male  group b             master's degree  standard
#
#   TEST PREPARATION COURSE  MATH SCORE  READING SCORE  WRITING SCORE
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93

# %%
# using apply function to make several specifiec functions on the data columns

# determine the length of the string in the column 
data["RACE"].apply(len)
# Out:
# 0      7
# 1      7
# 2      7
# 3      7
# 4      7
#       ..
# 995    7
# 996    7
# 997    7
# 998    7
# 999    7
# Name: RACE, Length: 1000, dtype: int64

# %%
# applying a function in the column 
def returnv (column) :
    return column.upper()

data["RACE"].apply(returnv)
# Out:
# 0      GROUP B
# 1      GROUP C
# 2      GROUP B
# 3      GROUP A
# 4      GROUP C
#         ...
# 995    GROUP E
# 996    GROUP C
# 997    GROUP C
# 998    GROUP D
# 999    GROUP D
# Name: RACE, Length: 1000, dtype: object

# %%
# applying lambda function on the data
data["RACE"].apply(lambda x : x.lower())
# Out:
# 0      group b
# 1      group c
# 2      group b
# 3      group a
# 4      group c
#         ...
# 995    group e
# 996    group c
# 997    group c
# 998    group d
# 999    group d
# Name: RACE, Length: 1000, dtype: object

# %%
# determine the column and values in every column of the data
data.apply(len)
# Out:
# GENDER                         1000
# RACE                           1000
# PARENTAL LEVEL OF EDUCATION    1000
# LUNCH                          1000
# TEST PREPARATION COURSE        1000
# MATH SCORE                     1000
# READING SCORE                  1000
# WRITING SCORE                  1000
# dtype: int64

# %%
# determine the minimum row in values
# data.apply(pd.Series.min) is the same using data.apply(lambda x : x.min())
data.apply(lambda x : x.min())
# Out:
# GENDER                                     female
# RACE                                      group a
# PARENTAL LEVEL OF EDUCATION    associate's degree
# LUNCH                                free/reduced
# TEST PREPARATION COURSE                 completed
# MATH SCORE                                      0
# READING SCORE                                  17
# WRITING SCORE                                  10
# dtype: object

# %% [markdown]
# # Add and Remove

# %%
# add a new column by concatinating
data["testing one"] = (data["TEST PREPARATION COURSE"]+ " " + data["LUNCH"])

# %%
# split variables in a column into two columns
data[["col1" , "col2"]] = data["testing one"].str.split(" ", expand = True)

# %%
# making a new row with default value if they was not mensioned in append
data = data.append({"col1" : "experiment"}, ignore_index = True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12340\4042150327.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append({"col1" : "experiment"}, ignore_index = True)

# %%
data.iloc[-1]
# note that we can use to append multible data set with the same concept
# Out:
# GENDER                                NaN
# RACE                                  NaN
# PARENTAL LEVEL OF EDUCATION           NaN
# LUNCH                                 NaN
# TEST PREPARATION COURSE               NaN
# MATH SCORE                            NaN
# READING SCORE                         NaN
# WRITING SCORE                         NaN
# testing one                           NaN
# col1                           experiment
# col2                                  NaN
# Name: 1000, dtype: object

# %% [markdown]
# # Delete and Drop

# %%
# delete colums col1 and col2 we have made
data.drop(columns = ["col1" , "col2"] , inplace = True)

# %%
# delete row that we have just created
# drop can take a filter.index in the data
# .drop(index = data[filt].index)
data.drop(index = 1000)
# Out:
#      GENDER     RACE PARENTAL LEVEL OF EDUCATION         LUNCH  \
# 0    female  group b           bachelor's degree      standard
# 1    female  group c                some college      standard
# 2      male  group b             master's degree      standard
# 3      male  group a          associate's degree  free/reduced
# 4      male  group c                some college      standard
# ..      ...      ...                         ...           ...
# 995  female  group e             master's degree      standard
# 996    male  group c                 high school  free/reduced
# 997  female  group c                 high school  free/reduced
# 998  female  group d                some college      standard
# 999  female  group d                some college  free/reduced
#
#     TEST PREPARATION COURSE  MATH SCORE  READING SCORE  WRITING SCORE  \
# 0                      none        72.0           72.0           74.0
# ...

# %% [markdown]
# ## Sorting Data
#
# #### Sorting by values
# data.sort_values(by ="col_name" , ascending = True , inplace = True)
#
# inplace = True makes the data be updated itself with new sorting, if i need to sort by values using to columns we can add a list of columns needed in by parameter: by = ["col1" , "col2"] , the same can be done in ascending to chaose the order needed of evry column.
#
# ### Sorting by index
#
# data.sort_index()
#
# ### Sorting by largest values
#
# if we nned to arrange values a specifc column we try:
#
# data["col_name"].nlargest(NumberOfRows)
#
# this line of code printing the column of the data not all info data so we can try this code to get the all information:
#
# data.nlargest(NumberOfRows , "col_name")

# %%
data.sort_values(by = ["MATH SCORE" , "READING SCORE" , "WRITING SCORE"] , ascending = [False , True, False])
# Out:
#       GENDER     RACE PARENTAL LEVEL OF EDUCATION         LUNCH  \
# 451   female  group e                some college      standard
# 623     male  group a                some college      standard
# 625     male  group d                some college      standard
# 458   female  group e           bachelor's degree      standard
# 916     male  group e           bachelor's degree      standard
# ...      ...      ...                         ...           ...
# 787   female  group b                some college      standard
# 17    female  group b            some high school  free/reduced
# 980   female  group b                 high school  free/reduced
# 59    female  group c            some high school  free/reduced
# 1000     NaN      NaN                         NaN           NaN
#
#      TEST PREPARATION COURSE  MATH SCORE  READING SCORE  WRITING SCORE  \
# 451                     none       100.0           92.0           97.0
# ...

# %%
data.sort_index()
# Out:
#       GENDER     RACE PARENTAL LEVEL OF EDUCATION         LUNCH  \
# 0     female  group b           bachelor's degree      standard
# 1     female  group c                some college      standard
# 2       male  group b             master's degree      standard
# 3       male  group a          associate's degree  free/reduced
# 4       male  group c                some college      standard
# ...      ...      ...                         ...           ...
# 996     male  group c                 high school  free/reduced
# 997   female  group c                 high school  free/reduced
# 998   female  group d                some college      standard
# 999   female  group d                some college  free/reduced
# 1000     NaN      NaN                         NaN           NaN
#
#      TEST PREPARATION COURSE  MATH SCORE  READING SCORE  WRITING SCORE  \
# 0                       none        72.0           72.0           74.0
# ...

# %% [markdown]
# ## Grouping and Aggregating - Analyzing and Exploring Your Data

# %%
data.describe()
# Out:
#        MATH SCORE  READING SCORE  WRITING SCORE
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data["GENDER"].value_counts()
# Out:
# female    517
# male      483
# Name: GENDER, dtype: int64

# %%
#the warning happen because not all columns have numeric values to get the median of them
data.median()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12340\3379578974.py:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# MATH SCORE       66.0
# READING SCORE    70.0
# WRITING SCORE    69.0
# dtype: float64

# %%
data.count()
# Out:
# GENDER                         1000
# RACE                           1000
# PARENTAL LEVEL OF EDUCATION    1000
# LUNCH                          1000
# TEST PREPARATION COURSE        1000
# MATH SCORE                     1000
# READING SCORE                  1000
# WRITING SCORE                  1000
# testing one                    1000
# dtype: int64

# %% [markdown]
# ### Getting the data of a specific value

# %%
# first way is filtering 
filt = data["GENDER"] == "female"
result = data.loc[filt]
result["RACE"].value_counts()
# Out:
# group c    180
# group d    129
# group b    103
# group e     69
# group a     36
# Name: RACE, dtype: int64

# %%
# second way is groupby and getGroup
gendergroup = data.groupby(["GENDER"])
gendergroup.get_group("female")
# Out:
#      GENDER     RACE PARENTAL LEVEL OF EDUCATION         LUNCH  \
# 0    female  group b           bachelor's degree      standard
# 1    female  group c                some college      standard
# 5    female  group b          associate's degree      standard
# 6    female  group b                some college      standard
# 9    female  group b                 high school  free/reduced
# ..      ...      ...                         ...           ...
# 993  female  group d           bachelor's degree  free/reduced
# 995  female  group e             master's degree      standard
# 997  female  group c                 high school  free/reduced
# 998  female  group d                some college      standard
# 999  female  group d                some college  free/reduced
#
#     TEST PREPARATION COURSE  MATH SCORE  READING SCORE  WRITING SCORE  \
# 0                      none        72.0           72.0           74.0
# ...

# %%
# using agg function to get the info with one or more statistical functions
# getting the mean and median math score of females
filt = data["GENDER"] == "female"
result = data.loc[filt]
result["MATH SCORE"].agg(["median" , "mean"])
# Out:
# median    65.000000
# mean      63.582205
# Name: MATH SCORE, dtype: float64

# %%
# using agg function to get the info with one or more statistical functions
# getting the count of stundard in lunch of females using lambda and apply methods
gendergroup["TEST PREPARATION COURSE"].apply(lambda x: x.str.contains("completed").count())
# Out:
# GENDER
# female    517
# male      483
# Name: TEST PREPARATION COURSE, dtype: int64

# %%
#### using concat to make a new datafram
scores = pd.concat([data["MATH SCORE"], data["READING SCORE"] ,data["WRITING SCORE"]], axis = "columns", sort =True)
### renaming the columns of the new dataframe
scores.rename(columns = {"MATH SCORE" :'Math', "READING SCORE": "Reading" , "WRITING SCORE":"Writing"}, inplace = True)

# %%
scores["Total"] = scores["Math"] + scores["Writing"] + scores["Reading"]
scores
# Out:
#       Math  Reading  Writing  Total
# 0     72.0     72.0     74.0  218.0
# 1     69.0     90.0     88.0  247.0
# 2     90.0     95.0     93.0  278.0
# 3     47.0     57.0     44.0  148.0
# 4     76.0     78.0     75.0  229.0
# ...    ...      ...      ...    ...
# 996   62.0     55.0     55.0  172.0
# 997   59.0     71.0     65.0  195.0
# 998   68.0     78.0     77.0  223.0
# 999   77.0     86.0     86.0  249.0
# 1000   NaN      NaN      NaN    NaN
#
# [1001 rows x 4 columns]

# %% [markdown]
# ## Cleaning Data Handling Missing Values

# %% [markdown]
# #### Drop values using dropna
# ###### in axis we choose what to remove from the data if it is a column or a row
# ###### in how we choos the way to delete that if there is a column with all , the data will not contain any values from columns have that value of null
# ##### subset is to choose one or more columns not to delete null values in them so you get the values of null in these columns
# data.dropna(axis = "column" , how = "any" OR "all" , subset = ["colname" , "col2"])
#
# #### if i have missing or nan in string no np.nan or the missing values are not clear we can use replace
# data.replace("Miss" , np.nan)

# %%
# to know the null values of a dataframe
data.isna()
# Out:
#       GENDER   RACE  PARENTAL LEVEL OF EDUCATION  LUNCH  \
# 0      False  False                        False  False
# 1      False  False                        False  False
# 2      False  False                        False  False
# 3      False  False                        False  False
# 4      False  False                        False  False
# ...      ...    ...                          ...    ...
# 996    False  False                        False  False
# 997    False  False                        False  False
# 998    False  False                        False  False
# 999    False  False                        False  False
# 1000    True   True                         True   True
#
#       TEST PREPARATION COURSE  MATH SCORE  READING SCORE  WRITING SCORE  \
# 0                       False       False          False          False
# 1                       False       False          False          False
# 2                       False       False          False          False
# ...

# %%
data.isnull().sum()
# Out:
# GENDER                         1
# RACE                           1
# PARENTAL LEVEL OF EDUCATION    1
# LUNCH                          1
# TEST PREPARATION COURSE        1
# MATH SCORE                     1
# READING SCORE                  1
# WRITING SCORE                  1
# testing one                    1
# dtype: int64

# %%
## filling missing values with zero
data.fillna(0).tail(3)
# Out:
#       GENDER     RACE PARENTAL LEVEL OF EDUCATION         LUNCH  \
# 998   female  group d                some college      standard
# 999   female  group d                some college  free/reduced
# 1000       0        0                           0             0
#
#      TEST PREPARATION COURSE  MATH SCORE  READING SCORE  WRITING SCORE  \
# 998                completed        68.0           78.0           77.0
# 999                     none        77.0           86.0           86.0
# 1000                       0         0.0            0.0            0.0
#
#              testing one
# 998   completed standard
# 999    none free/reduced
# 1000                   0

# %%
data.dropna("index" , how = "all").tail(3)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12340\229340655.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   data.dropna("index" , how = "all").tail(3)
#      GENDER     RACE PARENTAL LEVEL OF EDUCATION         LUNCH  \
# 997  female  group c                 high school  free/reduced
# 998  female  group d                some college      standard
# 999  female  group d                some college  free/reduced
#
#     TEST PREPARATION COURSE  MATH SCORE  READING SCORE  WRITING SCORE  \
# 997               completed        59.0           71.0           65.0
# 998               completed        68.0           78.0           77.0
# 999                    none        77.0           86.0           86.0
#
#                 testing one
# 997  completed free/reduced
# 998      completed standard
# 999       none free/reduced

# %% [markdown]
# ## Cleaning Data Casting Datatypes

# %%
# identify the datatypes of the dataset
scores.dtypes
# Out:
# Math       float64
# Reading    float64
# Writing    float64
# Total      float64
# dtype: object

# %%
## type of null or nan values
type(np.nan)
# Out:
# float

# %%
## casting float to int but we can not do that if there is null values
scores["Math"] = scores["Math"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[171], line 2
#       1 ## casting float to int but we can not do that if there is null values
# ----> 2 scores["Math"] = scores["Math"].astype(int)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# ...

# %%
## droppping null values
scores.dropna("index" , how = "all" , inplace = True)

# %%
# casting the column with int 
scores["Math"] = scores["Math"].astype(int)

# %%
# notify that the datatype has been changed
scores.dtypes
# note that if there is a string in the column we can replace it with another numerical values and casting them

# %% [markdown]
# ## Working with Dates and Time Series Data

# %%
data2 = pd.read_csv('ETH_1h.csv')
# making the function to get all dates of a specific column and edit tehe dates from the beginning of importing the dataset
funcdate = lambda x: pd.datetime.strptime(x, "%Y-%m-%d %I-%p")
trydate = pd.read_csv('ETH_1h.csv', parse_dates =["Date"] ,date_parser = funcdate)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12340\3028571816.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   funcdate = lambda x: pd.datetime.strptime(x, "%Y-%m-%d %I-%p")

# %%
data2.head(3)
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81

# %%
data2.dtypes
# Out:
# Date       object
# Symbol     object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume    float64
# dtype: object

# %%
# converting the date datatype from object to date
data2["Date"] = pd.to_datetime(data2["Date"]  , format = "%Y-%m-%d %I-%p")

# %%
data2["Date"]
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
data2["Date"].loc[0].day_name()
# Out:
# 'Friday'

# %%
# the dataset is edited from the start of the anlysis
trydate.head(3)
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81

# %%
# making a new column to get the name of date in the dataset
data2["DayOfDate"] = data2["Date"].dt.day_name()
data2["DayOfDate"]
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: DayOfDate, Length: 23674, dtype: object

# %%
# getting the starting date 
start = data2["Date"].min()
# getting the ending date
end = data2["Date"].max()
# getting the period in days
period = end - start
print("Starting date is " , start, "\n", "Ending date is ",end,"\n" , "With period: ", period)
# Out:
# Starting date is  2017-07-01 11:00:00
#  Ending date is  2020-03-13 20:00:00
#  With period:  986 days 09:00:00

# %%
# filtering by dates
filt = (data2["Date"] >= "2020") & (data2["Date"] >= "2019")
# note that if we need to filter by date [1-1-2020] for example , we will add pd.to_datetime("date we need")
data2.loc[filt].head(5)
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume  \
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
#
#   DayOfDate
# 0    Friday
# 1    Friday
# 2    Friday
# 3    Friday
# 4    Friday

# %%
# sorting by date
data2.set_index('Date' , inplace = True)

# %%
# slicing the date in data, accessing a column to get the answer of a function in that period
data2.loc['2019-12-31' : '2020-03-13']["Volume"].mean()
# Out:
# 1402757.0065595037

# %%
data2.resample("D").mean()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12340\1150833574.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data2.resample("D").mean()
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-01  266.581538  268.698462  261.861538  265.284615  2.198771e+06
# 2017-07-02  268.870833  272.438750  266.422083  269.782500  2.177595e+06
# 2017-07-03  279.241667  280.774167  276.599583  278.882083  1.459015e+06
# 2017-07-04  277.042083  278.034167  275.117500  276.743333  1.254579e+06
# 2017-07-05  265.147917  267.120000  262.834583  265.025833  1.797923e+06
# ...                ...         ...         ...         ...           ...
# 2020-03-09  200.680417  203.311667  197.860000  200.818333  3.804752e+06
# ...

# %%
High = data2["High"].resample("W")
Open.plot()
# Out:
# Date
# 2017-07-02    Axes(0.125,0.11;0.775x0.77)
# 2017-07-09    Axes(0.125,0.11;0.775x0.77)
# 2017-07-16    Axes(0.125,0.11;0.775x0.77)
# 2017-07-23    Axes(0.125,0.11;0.775x0.77)
# 2017-07-30    Axes(0.125,0.11;0.775x0.77)
#                          ...
# 2020-02-16    Axes(0.125,0.11;0.775x0.77)
# 2020-02-23    Axes(0.125,0.11;0.775x0.77)
# 2020-03-01    Axes(0.125,0.11;0.775x0.77)
# 2020-03-08    Axes(0.125,0.11;0.775x0.77)
# 2020-03-15    Axes(0.125,0.11;0.775x0.77)
# Freq: W-SUN, Name: Open, Length: 142, dtype: object

# %%
data2["High"].resample("W").max().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Reading/Writing Data to Different Sources

# %%
female1 = data.loc[data["GENDER"] == 'female'].to_csv("Femalecsv.csv", sep = '\t')

# %%
female2 = data.loc[data["GENDER"] == 'female'].to_excel("Femaleexcel.xlsx")

# %%
datafemale = pd.read_excel("Femaleexcel.xlsx", index_col = "Unnamed: 0")

# %%
datafemale
# Out:
#      GENDER     RACE PARENTAL LEVEL OF EDUCATION         LUNCH  \
# 0    female  group b           bachelor's degree      standard
# 1    female  group c                some college      standard
# 5    female  group b          associate's degree      standard
# 6    female  group b                some college      standard
# 9    female  group b                 high school  free/reduced
# ..      ...      ...                         ...           ...
# 993  female  group d           bachelor's degree  free/reduced
# 995  female  group e             master's degree      standard
# 997  female  group c                 high school  free/reduced
# 998  female  group d                some college      standard
# 999  female  group d                some college  free/reduced
#
#     TEST PREPARATION COURSE  MATH SCORE  READING SCORE  WRITING SCORE  \
# 0                      none          72             72             74
# ...

# %%
female3 = data.loc[data["GENDER"] == 'female'].to_json("Femalejson.json", orient= "records",lines = True )

# %%
pd.read_json("Femalejson.json", orient= "records",lines = True).head(3)
# Out:
#    GENDER     RACE PARENTAL LEVEL OF EDUCATION     LUNCH  \
# 0  female  group b           bachelor's degree  standard
# 1  female  group c                some college  standard
# 2  female  group b          associate's degree  standard
#
#   TEST PREPARATION COURSE  MATH SCORE  READING SCORE  WRITING SCORE  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          71             83             78
#
#           testing one
# 0       none standard
# 1  completed standard
# 2       none standard
